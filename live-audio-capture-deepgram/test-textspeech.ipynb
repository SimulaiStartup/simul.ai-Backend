# %% [markdown]
# ### Para rodar:
#
# 1. Crie um .env com a variável DEEPGRAM_API_KEY, disponível no google drive em um documento chamado keys
# 2. Instale - pyaudio, deepgram-sdk, python-dotenv

# %%
from deepgram import DeepgramClient
from dotenv import load_dotenv

key = load_dotenv()
# Create a Deepgram client using the DEEPGRAM_API_KEY from environment variables
deepgram = DeepgramClient(key)

# %%
from deepgram import LiveTranscriptionEvents, LiveOptions, Microphone
from pyaudio import *
import json

dg_connection = deepgram.listen.live.v("1")

def on_open(self, open, **kwargs):
    print(f"\n\n{open}\n\n")

def on_message(self, result, **kwargs):
    sentence = result.channel.alternatives[0].transcript
    if len(sentence) == 0:
        return
    print(f"speaker: {sentence}")

def on_metadata(self, metadata, **kwargs):
    print(f"\n\n{metadata}\n\n")

def on_speech_started(self, speech_started, **kwargs):
    print(f"\n\n{speech_started}\n\n")

def on_utterance_end(self, utterance_end, **kwargs):
    print(f"\n\n{utterance_end}\n\n")

def on_error(self, error, **kwargs):
    print(f"\n\n{error}\n\n")

def on_close(self, close, **kwargs):
    print(f"\n\n{close}\n\n")

dg_connection.on(LiveTranscriptionEvents.Open, on_open)
dg_connection.on(LiveTranscriptionEvents.Transcript, on_message)
dg_connection.on(LiveTranscriptionEvents.Metadata, on_metadata)
dg_connection.on(LiveTranscriptionEvents.SpeechStarted, on_speech_started)
dg_connection.on(LiveTranscriptionEvents.UtteranceEnd, on_utterance_end)
dg_connection.on(LiveTranscriptionEvents.Error, on_error)
dg_connection.on(LiveTranscriptionEvents.Close, on_close)

options: LiveOptions = LiveOptions(
    model="nova-2",
    punctuate=True,
    language="en-US", # Change to pt-BR for Brazilian Portuguese
    encoding="linear16",
    channels=1,
    sample_rate=16000,
    # To get UtteranceEnd, the following must be set:
    interim_results=True,
    utterance_end_ms="1000",
    vad_events=True,
)
dg_connection.start(options)

# create microphone
microphone = Microphone(dg_connection.send)

# start microphone
microphone.start()

# wait until finished
input("Press Enter to stop recording...\n\n")

# Wait for the microphone to close
microphone.finish()

# Indicate that we've finished
dg_connection.finish()

print("Finished")
# Out:
# {
#     "type": "Open"
# }
#
#
#
#
# {
#     "type": "SpeechStarted",
#     "channel": [
#         0,
#         1
#     ],
#     "timestamp": 0.08
# }
#
#
# speaker: So what is the
# speaker: Oh, what is the purpose for your
#
#
# {
#     "type": "SpeechStarted",
#     "channel": [
#         0,
#         1
#     ],
#     "timestamp": 2.04
# }
#
#
# speaker: being here today?
# speaker: being here today?
#
#
# {
#     "type": "SpeechStarted",
#     "channel": [
#         0,
#         1
#     ],
#     "timestamp": 4.08
# }
#
#
# speaker: I would
# speaker: I would like to purchase
# speaker: I would like to purchase a bomb
#
#
# {
#     "type": "SpeechStarted",
#     "channel": [
#         0,
#         1
#     ],
#     "timestamp": 7.23
# }
#
#
#
#
# {
#     "type": "Close"
# }
#
#
#
#
# {
#     "type": "UtteranceEnd",
#     "channel": [
#         0,
#         1
#     ],
#     "last_word_end": 6.23
# }
#
#
#
#
# {
#     "type": "Metadata",
#     "transaction_key": "deprecated",
#     "request_id": "bb428342-12d5-4356-aa8e-f4ee17d60dbf",
#     "sha256": "b0fed87d4595f1dfa9c21f568957d1aec3bdcb58c09b1f942e0ec56ce52c4098",
#     "created": "2024-04-25T12:31:15.314Z",
#     "duration": 7.681875,
#     "channels": 1,
#     "models": [
#         "1dbdfb4d-85b2-4659-9831-16b3c76229aa"
#     ],
#     "model_info": {
#         "1dbdfb4d-85b2-4659-9831-16b3c76229aa": {
#             "name": "2-general-nova",
#             "version": "2024-01-11.36317",
#             "arch": "nova-2"
#         }
#     }
# }
#
#
# Finished
